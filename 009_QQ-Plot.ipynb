# %% [markdown]
# # QQ-Plot

# %%
import numpy as np
import pylab
import scipy.stats as stats

# %%
# Generate random observations from Gaussian Distribution

std_norml = np.random.normal(loc=0,            # Mean 
                             scale=1,          # Standard-deviation
                             size=1000)        # Observations

# ------------------------------------------------------------------

# 0 to 100th percentile of std-normal

for i in range(0, 101):
    print(i, np.percentile(std_norml, i))
# Out:
# 0 -3.186747704012679
# 1 -2.36070966169066
# 2 -2.129865129266525
# 3 -1.9426525048554097
# 4 -1.760620824827102
# 5 -1.6441165075797515
# 6 -1.5357684172970008
# 7 -1.4668138904179795
# 8 -1.360812655013431
# 9 -1.3184247635543493
# 10 -1.2475793753293491
# 11 -1.1805700433954749
# 12 -1.1363851558332612
# 13 -1.0953849213658002
# 14 -1.0272882553065508
# 15 -1.000112676868078
# 16 -0.9393748607786041
# 17 -0.9038656943473115
# 18 -0.8556502803741024
# 19 -0.8259724005536144
# 20 -0.7859995388030607
# 21 -0.7421133870058237
# 22 -0.7038733742017506
# 23 -0.6765472073064639
# 24 -0.6333100335334925
# 25 -0.6072218699125095
# 26 -0.5893184590743339
# 27 -0.5706946855660093
# 28 -0.5413172211758669
# 29 -0.5179111513345797
# 30 -0.49124551166107766
# 31 -0.45260071120837153
# 32 -0.4342096615089028
# 33 -0.39812469432182707
# 34 -0.38264387034778424
# 35 -0.3510301311755082
# 36 -0.3316362192462474
# 37 -0.30867435284073574
# 38 -0.2930666257243618
# 39 -0.2522280140766978
# ...

# %% [markdown]
# ### Using normal distribution

# %%
# Generate 100 samples from N(20,5)

measurements = np.random.normal(loc=20, scale=5, size=1000)

stats.probplot(measurements, dist='norm', plot=pylab)

pylab.show()

# %% [markdown]
# ### Using uniform distribution

# %%
# generate 100 samples from N(20,5)
measurements = np.random.uniform(low=-1, high=1, size=10000)

stats.probplot(measurements, dist='norm', plot=pylab)
pylab.show()

# %% [markdown]
# X: Gaussian Distribution
#
# Y: Uniform Distribution

# %% [markdown]
# The more and more points which are going father and farther away from the straight line... What this means is that in the extreme end of my distribution points are diverging more.
